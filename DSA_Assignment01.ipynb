# %%
import pandas as pd

# %% [markdown]
# # 1

# %%
data = pd.read_excel("C:/Users/USER/Downloads/iris.xls")

# %% [markdown]
# # 2

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data.sample(10)
# Out:
#       SL   SW   PL   PW   Classification
# 142  5.8  2.7  5.1  1.9   Iris-virginica
# 138  6.0  3.0  4.8  1.8   Iris-virginica
# 31   5.4  3.4  1.5  0.4      Iris-setosa
# 12   4.8  3.0  1.4  0.1      Iris-setosa
# 103  6.3  2.9  5.6  1.8   Iris-virginica
# 92   5.8  2.6  4.0  1.2  Iris-versicolor
# 85   6.0  3.4  4.5  1.6  Iris-versicolor
# 32   5.2  4.1  1.5  0.1      Iris-setosa
# 1    4.9  3.0  1.4  0.2      Iris-setosa
# 107  7.3  2.9  6.3  1.8   Iris-virginica

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
data.shape
# Out:
# (150, 5)

# %%
print(data)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 3

# %%
mean_data = data["SL"].mean()
print("\nMean:", mean_data)
# Out:
# Mean: 5.843333333333335

# %%
mean_data = data["SW"].mean()
print("\nMean:", mean_data)
# Out:
# Mean: 3.0540000000000007

# %%
mean_data = data["PL"].mean()
print("\nMean:", mean_data)
# Out:
# Mean: 3.7586666666666693

# %%
mean_data = data["PW"].mean()
print("\nMean:", mean_data)
# Out:
# Mean: 1.1986666666666672

# %% [markdown]
# # 4

# %%
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
data. isnull(). sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data['SL'])
plt.show()

# %%
plt.hist(data['SL'])
plt.hist(data['PL'])
plt.hist(data['SW'])
plt.hist(data['PW'])
plt.show()

# %%
plt.bar(data['SL'], height=0.1)
plt.bar(data['PL'], height=0.1)
plt.bar(data['SW'], height=0.1)
plt.bar(data['PW'], height=0.1)
plt.show()

# %%
plt.bar(data['SL'], height  = 0.1, width = 0.1)

plt.show()

# %%
plt.bar(data['SL'], height=0.1, width=0.1)
plt.bar(data['PL'], height=0.1, width=0.1)
plt.bar(data['SW'], height=0.1, width=0.1)
plt.bar(data['PW'], height=0.1, width=0.1)
plt.show()

# %%
plt.plot(data['SL'], marker = 'o', ms = 2)
plt.show()

# %%
plt.plot(data['SL'], marker = 'o', ms = 2)
plt.plot(data['PL'], marker = 'o', ms = 2)
plt.plot(data['SW'], marker = 'o', ms = 2)
plt.plot(data['PW'], marker = 'o', ms = 2)
plt.show()

# %%
plt.pie(data['SL'])
plt.pie(data['PL'])
plt.pie(data['SW'])
plt.pie(data['PW'])
plt.show()
